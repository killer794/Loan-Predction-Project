# %%
import pandas as pdf

# %%
rtrain = pd.read_csv("/Users/sagarjoshi/Desktop/Project/salePrediction/Train_UWu5bXk.txt")

# %%
rtrain.shape
# Out:
# (8523, 12)

# %%
rtrain.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
rtrain=rtrain.drop("Item_Identifier",axis=1)

# %%
rtrain=rtrain.drop("Outlet_Identifier",axis=1)

# %%
rtrain.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
rtrain.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
#univariate annalysis
rtrain["Item_Weight"].plot.hist()

# %%
rtrain["Item_Fat_Content"].value_counts().plot.bar()

# %%
rtrain["Item_Visibility"].plot.hist()

# %%
rtrain["Item_Type"].value_counts().plot.bar()

# %%
rtrain["Item_MRP"].plot.hist()

# %%
rtrain["Item_Outlet_Sales"].plot.hist()

# %%
rtrain["Outlet_Size"].value_counts().plot.bar()

# %%
rtrain["Outlet_Location_Type"].value_counts().plot.bar()

# %%
rtrain["Outlet_Type"].value_counts().plot.bar()

# %%
#BiVariate annalysis
rtrain.plot.scatter("Item_Weight","Item_Outlet_Sales")

# %%
rtrain.plot.scatter("Item_Visibility","Item_Outlet_Sales")

# %%
rtrain.plot.scatter("Item_MRP","Item_Outlet_Sales")

# %%
rtrain.isnull().sum()
# Out:
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
import numpy as np

# %%
np.mean(rtrain["Item_Weight"])
# Out:
# 12.857645184136183

# %%
rtrain["Item_Weight"].fillna(12.857645184136183,inplace=True)

# %%
rtrain["Outlet_Size"].fillna("Medium",inplace=True)

# %%
rtrain.isnull().sum()
# Out:
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
rtest = pd.read_csv("/Users/sagarjoshi/Desktop/Project/salePrediction/Test_u94Q5KV.txt")

# %%
rtest=rtest.drop("Item_Identifier",axis=1)

# %%
rtest=rtest.drop("Outlet_Identifier",axis=1)

# %%
rtest.shape
# Out:
# (5681, 9)

# %%
train = pd.get_dummies(rtrain)

# %%
train.shape
# Out:
# (8523, 36)

# %%
rtest.shape
# Out:
# (5681, 9)

# %%
rtest.isnull().sum()
# Out:
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
np.mean(rtest["Item_Weight"])
# Out:
# 12.695633368756374

# %%
rtest["Item_Weight"].fillna(12.695633368756374,inplace=True)

# %%
rtest["Outlet_Size"].fillna("Medium",inplace=True)

# %%
rtest.isnull().sum()
# Out:
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
test.shape
# Out:
# (5681, 1588)

# %%
x_train = train.drop("Item_Outlet_Sales",axis=1)

# %%
y_train = train["Item_Outlet_Sales"]

# %%
test = pd.get_dummies(rtest)

# %%
from sklearn.linear_model import LinearRegression

# %%
lreg = LinearRegression()

# %%
lreg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lreg.score(x_train,y_train)
# Out:
# 0.563538862254919

# %%
train.shape
# Out:
# (8523, 36)

# %%
test.shape
# Out:
# (5681, 35)

# %%
rtest.shape
# Out:
# (5681, 9)

# %%
predLreg=lreg.predict(test)

# %%
predLreg
# Out:
# array([1792.1034791 , 1467.40151762, 1882.38197173, ..., 1832.7227012 ,
#        3628.51198813, 1298.03647644])

# %%
testt=pd.read_csv("/Users/sagarjoshi/Desktop/Project/salePrediction/Test_u94Q5KV.txt")

# %%
pred = pd.DataFrame()

# %%
pred["Item_Identifier"] = testt["Item_Identifier"]

# %%
pred["Outlet_Identifier"] = testt["Outlet_Identifier"]

# %%
pred["Item_Outlet_Sales"] = predLreg

# %%
pred.head()
# Out:
#   Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0           FDW58            OUT049        1792.103479
# 1           FDW14            OUT017        1467.401518
# 2           NCN55            OUT010        1882.381972
# 3           FDQ58            OUT017        2621.118943
# 4           FDY38            OUT027        5138.577117

# %%
pred.to_csv("salePrediction.csv",header=True, index=False)

# %%
from PIL import Image

# %%
img  = Image.open("/Users/sagarjoshi/Desktop/Project/salePrediction/score.png")

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1199x673 at 0x1A2732D860>
